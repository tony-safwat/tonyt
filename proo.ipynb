# %% [markdown]
# ## linear regression

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\microsoft\anaconda3\lib\site-packages (1.0.2)
# WARNING: Ignoring invalid distribution -ycler (c:\users\microsoft\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ycler (c:\users\microsoft\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ycler (c:\users\microsoft\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ycler (c:\users\microsoft\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ycler (c:\users\microsoft\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ycler (c:\users\microsoft\anaconda3\lib\site-packages)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\microsoft\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\microsoft\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\microsoft\anaconda3\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\microsoft\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split





from sklearn.metrics import mean_squared_error,r2_score
import pandas as pd

# %%
dataset=pd.read_excel(r"G:\مدرسةاحمدضيفالله\G1(data+assesments)\S2\G1. 1.5\iceee.xlsx")

# %%
x=dataset["Temperature"].values.reshape(-1, 1)
y=dataset["Ice Cream Profits"].values.reshape(-1, 1)

# %%
x
# Out:
# array([[ 39],
#        [ 40],
#        [ 41],
#        [ 42],
#        [ 43],
#        [ 43],
#        [ 44],
#        [ 44],
#        [ 45],
#        [ 45],
#        [ 45],
#        [ 46],
#        [ 46],
#        [ 47],
#        [ 48],
#        [ 48],
#        [ 48],
#        [ 48],
#        [ 48],
#        [ 48],
#        [ 49],
#        [ 49],
#        [ 50],
#        [ 50],
#        [ 50],
#        [ 50],
#        [ 50],
#        [ 51],
#        [ 51],
#        [ 52],
#        [ 52],
#        [ 52],
#        [ 52],
#        [ 52],
#        [ 53],
#        [ 53],
#        [ 53],
#        [ 53],
#        [ 54],
#        [ 54],
#        [ 54],
#        [ 54],
#        [ 54],
#        [ 54],
#        [ 54],
#        [ 54],
#        [ 54],
#        [ 55],
#        [ 55],
#        [ 55],
#        [ 55],
#        [ 56],
#        [ 56],
#        [ 57],
#        [ 57],
#        [ 58],
#        [ 58],
#        [ 58],
#        [ 58],
#        [ 58],
#        [ 58],
#        [ 59],
#        [ 59],
#        [ 59],
#        [ 59],
#        [ 59],
#        [ 59],
#        [ 59],
#        [ 59],
#        [ 60],
#        [ 60],
#        [ 60],
#        [ 60],
#        [ 60],
#        [ 61],
#        [ 61],
#        [ 61],
#        [ 61],
#        [ 61],
#        [ 61],
#        [ 61],
#        [ 61],
#        [ 61],
#        [ 62],
#        [ 62],
#        [ 62],
#        [ 62],
#        [ 63],
#        [ 63],
#        [ 63],
#        [ 63],
#        [ 63],
#        [ 64],
#        [ 64],
#        [ 64],
#        [ 64],
#        [ 64],
#        [ 64],
#        [ 64],
#        [ 64],
#        [ 64],
#        [ 65],
#        [ 65],
#        [ 65],
#        [ 65],
#        [ 65],
#        [ 65],
#        [ 65],
#        [ 65],
#        [ 65],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 66],
#        [ 67],
#        [ 67],
#        [ 67],
#        [ 67],
#        [ 67],
#        [ 67],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 68],
#        [ 69],
#        [ 69],
#        [ 69],
#        [ 69],
#        [ 69],
#        [ 69],
#        [ 70],
#        [ 70],
#        [ 70],
#        [ 70],
#        [ 70],
#        [ 70],
#        [ 70],
#        [ 70],
#        [ 70],
#        [ 71],
#        [ 71],
#        [ 71],
#        [ 71],
#        [ 71],
#        [ 71],
#        [ 71],
#        [ 71],
#        [ 71],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 72],
#        [ 73],
#        [ 73],
#        [ 73],
#        [ 73],
#        [ 73],
#        [ 73],
#        [ 73],
#        [ 73],
#        [ 73],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 74],
#        [ 75],
#        [ 75],
#        [ 75],
#        [ 75],
#        [ 75],
#        [ 75],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 76],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 77],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 78],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 79],
#        [ 80],
#        [ 80],
#        [ 80],
#        [ 80],
#        [ 80],
#        [ 80],
#        [ 80],
#        [ 80],
#        [ 80],
#        [ 81],
#        [ 81],
#        [ 81],
#        [ 81],
#        [ 81],
#        [ 81],
#        [ 81],
#        [ 81],
#        [ 81],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 82],
#        [ 83],
#        [ 83],
#        [ 83],
#        [ 83],
#        [ 83],
#        [ 83],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 84],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 85],
#        [ 86],
#        [ 86],
#        [ 86],
#        [ 86],
#        [ 86],
#        [ 86],
#        [ 86],
#        [ 86],
#        [ 87],
#        [ 87],
#        [ 87],
#        [ 87],
#        [ 87],
#        [ 87],
#        [ 88],
#        [ 88],
#        [ 88],
#        [ 89],
#        [ 89],
#        [ 89],
#        [ 89],
#        [ 90],
#        [ 90],
#        [ 90],
#        [ 90],
#        [ 90],
#        [ 90],
#        [ 90],
#        [ 91],
#        [ 91],
#        [ 91],
#        [ 92],
#        [ 92],
#        [ 92],
#        [ 92],
#        [ 93],
#        [ 93],
#        [ 94],
#        [ 94],
#        [ 95],
#        [ 95],
#        [ 95],
#        [ 95],
#        [ 96],
#        [ 96],
#        [ 96],
#        [ 97],
#        [ 98],
#        [ 99],
#        [ 99],
#        [ 99],
#        [101],
#        [101]], dtype=int64)

# %%
y
# Out:
# array([[13.17],
#        [11.88],
#        [18.82],
#        [18.65],
#        [17.02],
#        [15.88],
#        [19.07],
#        [19.57],
#        [21.62],
#        [22.34],
#        [19.23],
#        [21.25],
#        [19.81],
#        [22.12],
#        [24.22],
#        [24.68],
#        [23.78],
#        [26.41],
#        [25.01],
#        [22.29],
#        [27.81],
#        [23.54],
#        [22.89],
#        [25.68],
#        [27.29],
#        [27.64],
#        [27.31],
#        [21.93],
#        [32.18],
#        [30.67],
#        [28.05],
#        [28.82],
#        [27.87],
#        [29.39],
#        [32.6 ],
#        [31.62],
#        [25.71],
#        [28.48],
#        [30.09],
#        [33.58],
#        [29.75],
#        [31.94],
#        [33.71],
#        [28.37],
#        [27.41],
#        [27.99],
#        [30.37],
#        [27.68],
#        [29.53],
#        [33.91],
#        [34.19],
#        [33.22],
#        [34.47],
#        [30.89],
#        [35.8 ],
#        [33.44],
#        [36.79],
#        [31.56],
#        [35.13],
#        [36.11],
#        [32.39],
#        [38.18],
#        [29.69],
#        [38.47],
#        [37.74],
#        [36.71],
#        [32.29],
#        [37.5 ],
#        [35.33],
#        [35.06],
#        [36.25],
#        [40.25],
#        [39.69],
#        [40.95],
#        [37.96],
#        [38.1 ],
#        [38.21],
#        [37.3 ],
#        [39.53],
#        [37.42],
#        [39.42],
#        [38.16],
#        [37.66],
#        [39.04],
#        [41.44],
#        [40.19],
#        [37.93],
#        [50.17],
#        [44.15],
#        [41.58],
#        [40.59],
#        [39.17],
#        [40.57],
#        [40.28],
#        [41.21],
#        [44.85],
#        [40.94],
#        [40.14],
#        [38.57],
#        [44.07],
#        [44.1 ],
#        [47.36],
#        [45.38],
#        [41.09],
#        [43.78],
#        [42.72],
#        [42.1 ],
#        [43.28],
#        [44.31],
#        [42.71],
#        [43.03],
#        [42.16],
#        [46.74],
#        [47.68],
#        [44.48],
#        [47.52],
#        [44.98],
#        [45.07],
#        [45.42],
#        [47.36],
#        [48.26],
#        [51.75],
#        [45.05],
#        [40.65],
#        [48.65],
#        [45.26],
#        [46.04],
#        [44.85],
#        [42.94],
#        [50.62],
#        [45.65],
#        [49.37],
#        [45.89],
#        [50.74],
#        [47.17],
#        [49.6 ],
#        [41.68],
#        [46.9 ],
#        [47.35],
#        [47.73],
#        [43.73],
#        [47.47],
#        [51.38],
#        [41.74],
#        [49.88],
#        [47.78],
#        [42.5 ],
#        [48.77],
#        [49.46],
#        [50.87],
#        [49.12],
#        [49.95],
#        [50.31],
#        [49.32],
#        [52.67],
#        [52.05],
#        [48.82],
#        [53.33],
#        [54.59],
#        [53.77],
#        [49.6 ],
#        [52.17],
#        [46.74],
#        [53.04],
#        [49.34],
#        [55.04],
#        [57.18],
#        [51.26],
#        [53.78],
#        [51.55],
#        [50.01],
#        [53.59],
#        [52.47],
#        [48.96],
#        [53.57],
#        [50.79],
#        [52.13],
#        [52.42],
#        [54.67],
#        [51.82],
#        [53.21],
#        [54.4 ],
#        [55.01],
#        [54.08],
#        [53.97],
#        [55.28],
#        [54.36],
#        [53.62],
#        [50.65],
#        [55.52],
#        [58.61],
#        [50.64],
#        [54.28],
#        [53.95],
#        [53.44],
#        [57.1 ],
#        [54.26],
#        [55.34],
#        [53.71],
#        [57.84],
#        [55.91],
#        [58.62],
#        [58.85],
#        [52.84],
#        [56.59],
#        [59.43],
#        [59.69],
#        [53.83],
#        [59.41],
#        [53.17],
#        [53.48],
#        [59.94],
#        [60.31],
#        [60.33],
#        [53.82],
#        [53.07],
#        [59.48],
#        [54.1 ],
#        [56.33],
#        [59.87],
#        [60.75],
#        [56.43],
#        [60.86],
#        [55.07],
#        [58.39],
#        [58.72],
#        [57.52],
#        [56.33],
#        [57.47],
#        [58.13],
#        [60.46],
#        [60.33],
#        [60.89],
#        [62.58],
#        [61.22],
#        [59.62],
#        [58.31],
#        [59.12],
#        [57.93],
#        [57.25],
#        [62.2 ],
#        [59.7 ],
#        [64.82],
#        [57.06],
#        [62.52],
#        [59.93],
#        [61.71],
#        [59.49],
#        [67.42],
#        [56.34],
#        [59.69],
#        [57.44],
#        [64.63],
#        [55.47],
#        [61.22],
#        [62.79],
#        [59.91],
#        [61.59],
#        [63.46],
#        [64.45],
#        [65.42],
#        [61.82],
#        [64.36],
#        [58.11],
#        [59.47],
#        [65.86],
#        [61.52],
#        [62.12],
#        [64.23],
#        [62.36],
#        [62.32],
#        [64.97],
#        [66.15],
#        [64.02],
#        [63.41],
#        [61.85],
#        [65.49],
#        [64.39],
#        [66.06],
#        [64.86],
#        [62.85],
#        [66.57],
#        [65.54],
#        [62.58],
#        [63.29],
#        [64.38],
#        [60.78],
#        [65.66],
#        [66.61],
#        [65.12],
#        [63.13],
#        [63.35],
#        [65.4 ],
#        [65.41],
#        [68.28],
#        [64.1 ],
#        [66.26],
#        [63.63],
#        [67.58],
#        [68.54],
#        [65.2 ],
#        [67.93],
#        [67.88],
#        [69.71],
#        [64.22],
#        [61.82],
#        [68.28],
#        [62.99],
#        [64.96],
#        [65.99],
#        [70.3 ],
#        [64.31],
#        [69.59],
#        [68.35],
#        [69.66],
#        [71.46],
#        [69.9 ],
#        [69.19],
#        [67.97],
#        [64.85],
#        [70.43],
#        [68.48],
#        [70.29],
#        [65.19],
#        [68.  ],
#        [70.64],
#        [69.67],
#        [74.69],
#        [69.78],
#        [73.16],
#        [71.51],
#        [73.32],
#        [74.09],
#        [71.12],
#        [67.58],
#        [77.39],
#        [75.11],
#        [74.8 ],
#        [73.94],
#        [75.94],
#        [79.31],
#        [81.81],
#        [75.58],
#        [78.2 ],
#        [75.6 ],
#        [75.04],
#        [77.41],
#        [79.76],
#        [77.18],
#        [80.94],
#        [75.7 ],
#        [78.2 ],
#        [80.75],
#        [80.97],
#        [80.98],
#        [80.02],
#        [82.83],
#        [80.95],
#        [82.5 ],
#        [84.12],
#        [85.13],
#        [87.08],
#        [89.29],
#        [81.91],
#        [85.02]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=55)

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=reg.predict(x_test)

# %%
y_predict
# Out:
# array([[60.45173504],
#        [36.57239874],
#        [40.15429919],
#        [44.93016645],
#        [28.21463104],
#        [70.00346956],
#        [67.61553593],
#        [34.18446512],
#        [54.48190097],
#        [47.31810008],
#        [30.60256467],
#        [43.73619963],
#        [62.83966867],
#        [58.06380141],
#        [41.348266  ],
#        [28.21463104],
#        [44.93016645],
#        [58.06380141],
#        [70.00346956],
#        [48.51206689],
#        [60.45173504],
#        [55.67586778],
#        [24.6327306 ],
#        [47.31810008],
#        [43.73619963],
#        [37.76636556],
#        [35.37843193],
#        [49.70603371],
#        [47.31810008],
#        [71.19743637],
#        [64.03363548],
#        [27.02066423],
#        [59.25776822],
#        [53.28793415],
#        [70.00346956],
#        [25.82669741],
#        [41.348266  ],
#        [66.42156911],
#        [18.66289652],
#        [52.09396734],
#        [43.73619963],
#        [42.54223282],
#        [48.51206689],
#        [37.76636556],
#        [54.48190097],
#        [46.12413326],
#        [43.73619963],
#        [38.96033237],
#        [50.90000052],
#        [17.46892971],
#        [61.64570185],
#        [62.83966867],
#        [18.66289652],
#        [65.2276023 ],
#        [49.70603371],
#        [25.82669741],
#        [56.8698346 ],
#        [36.57239874],
#        [23.43876378],
#        [30.60256467],
#        [50.90000052],
#        [53.28793415],
#        [47.31810008],
#        [62.83966867],
#        [53.28793415],
#        [68.80950274],
#        [54.48190097],
#        [56.8698346 ],
#        [56.8698346 ],
#        [46.12413326],
#        [42.54223282],
#        [62.83966867],
#        [56.8698346 ]])

# %%
m=mean_squared_error(y_test,y_predict)

# %%
r2=r2_score(y_test,y_predict)

# %%
m
# Out:
# 6.933497518664732

# %%
r2
# Out:
# 0.9642609951951698

# %%
y

# %%
import numpy as np
yy=np.array([100])
o=yy.reshape(-1,1)

# %%
y_predt=reg.predict(o)

# %%
y_predt
# Out:
# array([[85.52503815]])

# %% [markdown]
# # example

# %%
from sklearn.linear_model import LinearRegression
#from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import pandas as pd

# %%
data=pd.DataFrame({"number of rooms":[1,2,3,5,6,7,8],
                  "price":[150,200,250,350,400,450,500]})

# %%
input_data=data["number of rooms"].values.reshape(-1, 1)
output_data=data["price"].values.reshape(-1, 1)

# %%
reg_model=LinearRegression()

# %%
reg_model.fit(input_data,output_data)
# Out:
# LinearRegression()

# %%
import numpy as np
test=np.array([4]).reshape(-1,1)

reg_model.predict(test)
# Out:
# array([[300.]])

# %% [markdown]
# ## polynomial regression

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\2033\Desktop\models\Student_Marks.csv")

# %%
x=dataset["time_study"].values.reshape(-1, 1)
y=dataset["Marks"].values.reshape(-1, 1)

# %%
plt.scatter(x,y,color="red")

plt.title("hgwwe")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=55)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2)

# %% [markdown]
# ## y=b0+b1x+b2x(^2)         y=mx+b

# %%
xTrain_poly=poly.fit_transform(x_train)
xTest_poly=poly.fit_transform(x_test)

# %%
reg_model=LinearRegression()
reg_model.fit(xTrain_poly,y_train)
# Out:
# LinearRegression()

# %%
reg_model.predict(xTest_poly)
# Out:
# array([[18703.38292434],
#        [19569.77955346],
#        [24616.78089535],
#        [20164.62463103],
#        [23532.6199261 ],
#        [25476.32911654],
#        [21347.36845792],
#        [24112.95041755],
#        [22638.10127196],
#        [19356.15503634],
#        [22461.80849854],
#        [21637.54233613],
#        [20372.80861246],
#        [20088.95667021],
#        [18834.46156254],
#        [20335.72457811],
#        [22051.6192838 ],
#        [19154.4351863 ],
#        [24832.22633519],
#        [24959.49560452],
#        [25396.36689095],
#        [23624.41332645],
#        [21421.00495121],
#        [21321.83752174],
#        [25209.31619305],
#        [19450.10727712],
#        [22818.58230848],
#        [21047.22418035],
#        [20707.61329614],
#        [24737.4437173 ],
#        [23508.32174891],
#        [22014.72232811],
#        [19087.85642171],
#        [22440.47374215],
#        [19057.79809802],
#        [21167.56476058],
#        [23125.34602964],
#        [19504.45632603],
#        [19758.18694549],
#        [19493.12842902],
#        [21579.81949572],
#        [23385.86686402],
#        [19642.57814956],
#        [20733.49121953],
#        [20364.78466188],
#        [22365.84136164],
#        [25487.02258334],
#        [21931.04319837],
#        [24892.04202949],
#        [21216.55262273],
#        [20153.22196488],
#        [21989.240197  ],
#        [23960.37579847],
#        [24404.45946594],
#        [20222.72678212],
#        [23444.44569916],
#        [23488.73988296],
#        [24732.86762216],
#        [20316.3013547 ],
#        [20694.08586382],
#        [20576.1704628 ],
#        [20663.19150366],
#        [24220.90855441],
#        [20707.61329614],
#        [22481.90739758],
#        [21659.18012758],
#        [19026.81307696],
#        [21114.16092497],
#        [19242.71122301],
#        [24187.54237107],
#        [24199.85683269],
#        [23746.99274824],
#        [20974.26427679],
#        [22412.42677753],
#        [22380.07005913],
#        [20721.57463035],
#        [25440.2568873 ],
#        [21911.2207805 ],
#        [21519.55415314],
#        [25150.88621051],
#        [23712.75634242],
#        [23181.73502672],
#        [24621.60745354],
#        [21321.40165837],
#        [22360.76801215],
#        [23351.05409976],
#        [20628.09205365],
#        [23600.21637926],
#        [20647.34978627],
#        [23237.18408364],
#        [23707.46396649],
#        [23437.75707037],
#        [23145.46895583],
#        [22768.41331024],
#        [23918.79182615],
#        [22231.16832273],
#        [20305.41573168],
#        [23257.56434112],
#        [18934.30191942],
#        [21025.97955535],
#        [21957.07840627],
#        [22701.24909522],
#        [19521.17870143],
#        [23175.64621069],
#        [23865.48860788],
#        [21922.53259541],
#        [20962.41394447],
#        [20901.15939596],
#        [19693.66539896],
#        [25161.07951999],
#        [19522.88364257],
#        [24449.33012893],
#        [24022.43855537],
#        [24491.78756306],
#        [21633.73377554],
#        [20927.89194511],
#        [19616.50825151],
#        [25541.00875747],
#        [21973.91943187],
#        [22461.45947469],
#        [24771.70035449],
#        [23642.0057491 ],
#        [22217.88456367],
#        [19404.70610703],
#        [22571.05154688],
#        [22953.35643724],
#        [20734.54006398],
#        [21066.21996121],
#        [19494.00321483],
#        [23073.89184807],
#        [20770.6957632 ],
#        [23170.36995549],
#        [25399.99611179],
#        [24134.01219639],
#        [21382.42265206],
#        [20071.39883505],
#        [19433.60332683],
#        [25236.48497277],
#        [25367.7167434 ],
#        [25375.29102966],
#        [20921.08721592],
#        [23037.26454377],
#        [22731.75546429],
#        [23751.62138865],
#        [24907.50995357],
#        [23420.65737774],
#        [20742.02586643],
#        [19936.70397306],
#        [23970.6100327 ],
#        [18981.43238562],
#        [25446.40053957],
#        [23606.7256468 ],
#        [23184.57677827],
#        [19295.76931165],
#        [19763.80114739],
#        [23500.08910469],
#        [19247.8761627 ],
#        [21550.52761384],
#        [19453.87809727],
#        [23270.12270438],
#        [20693.75250403],
#        [18838.16402362],
#        [19969.45444708],
#        [22831.1090025 ],
#        [22435.7397566 ],
#        [19287.89683518],
#        [18721.96077394],
#        [21618.4544811 ],
#        [23148.15612761],
#        [24550.41629712],
#        [21309.05427311],
#        [24384.51996621],
#        [20065.78216033],
#        [23495.89669565],
#        [20565.39635729],
#        [18753.24749807],
#        [22523.58340968],
#        [24361.72063765],
#        [19264.38182425],
#        [21164.86383228],
#        [19831.84643017],
#        [22162.46779485],
#        [24007.94929829],
#        [22693.27504064],
#        [19352.1657247 ],
#        [22821.3992235 ],
#        [18711.20862887],
#        [20828.91496359],
#        [23747.40416271],
#        [25111.09039138],
#        [24584.21528747],
#        [20189.50728283],
#        [24211.75890848],
#        [25400.42309771],
#        [19925.84052246],
#        [21112.33072897],
#        [19747.79609636],
#        [24065.62450515],
#        [20220.79949067],
#        [20831.87852163]])

# %% [markdown]
# ## logistic regression

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Load the data
data = pd.read_excel(r"C:\Users\Microsoft\Desktop\canncer.xlsx")

# %%
data.head()
# Out:
#    Year  Age  Menopause  Tumor Size (cm)  Inv-Nodes Breast  Metastasis  \
# 0  2019   40          1                2          0  Right           0
# 1  2019   39          1                2          0   Left           0
# 2  2019   45          0                4          0   Left           0
# 3  2019   26          1                3          0   Left           0
# 4  2019   21          1                1          0  Right           0
#
#   Breast Quadrant History Diagnosis Result
# 0     Upper inner       0           Benign
# 1     Upper outer       0           Benign
# 2     Lower outer       0           Benign
# 3     Lower inner       1           Benign
# 4     Upper outer       1           Benign

# %%
# Prepare the data
data["Diagnosis Result"] = pd.get_dummies(data["Diagnosis Result"], drop_first=True)

# %%
data.head(10)
# Out:
#    Year  Age  Menopause  Tumor Size (cm)  Inv-Nodes Breast  Metastasis  \
# 0  2019   40          1                2          0  Right           0
# 1  2019   39          1                2          0   Left           0
# 2  2019   45          0                4          0   Left           0
# 3  2019   26          1                3          0   Left           0
# 4  2019   21          1                1          0  Right           0
# 5  2019   50          0                5          1  Right           1
# 6  2019   58          0                6          1  Right           1
# 7  2019   21          1                3          0   Left           0
# 8  2019   35          1                4          0   Left           0
# 9  2019   42          1                2          0  Right           0
#
#   Breast Quadrant History  Diagnosis Result
# 0     Upper inner       0                 0
# 1     Upper outer       0                 0
# 2     Lower outer       0                 0
# 3     Lower inner       1                 0
# 4     Upper outer       1                 0
# 5     Lower outer       0                 1
# 6     Upper outer       0                 1
# 7     Upper inner       0                 0
# 8     Upper outer       0                 0
# 9     Lower outer       1                 0

# %%
x=data[["Age", "Tumor Size (cm)"]]
y=data["Diagnosis Result"]

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# Train the logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
# Evaluate the performance of the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1-score:", f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.8837209302325582
# Precision: 0.9375
# Recall: 0.7894736842105263
# F1-score: 0.8571428571428572
